# %%
from scheduler import full_product_update
# Out:
# microservice_edc_pull

# %%
full_product_update()
# Out:
# Something went very wrong in the convert function!
# Something went very wrong in the convert function!
# Something went very wrong in the convert function!
# Something went very wrong in the convert function!
# Something went very wrong in the convert function!
# Something went very wrong in the convert function!
# Something went very wrong in the convert function!
# Something went very wrong in the convert function!
# Something went very wrong in the convert function!
# Something went very wrong in the convert function!
# Something went very wrong in the convert function!
# Something went very wrong in the convert function!
# Something went very wrong in the convert function!
# Something went very wrong in the convert function!
# Something went very wrong in the convert function!
# Something went very wrong in the convert function!
# Something went very wrong in the convert function!
# Something went very wrong in the convert function!
# ...
